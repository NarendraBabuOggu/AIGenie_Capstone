# %%
from sklearn.naive_bayes import *
from sklearn.dummy import *
from sklearn.ensemble import *
from sklearn.neighbors import *
from sklearn.tree import *
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.calibration import *
from sklearn.linear_model import *
from sklearn.multiclass import *
from sklearn.svm import *
from sklearn.metrics import f1_score, confusion_matrix
import pandas as pd
import os
from sklearn.model_selection import train_test_split, cross_val_score

np.random.seed(3)

# %%
def analyze_models(classifiers, vectorizers, train_data, test_data):
    results = []
    for classifier in classifiers:
      for vectorizer in vectorizers:
        string = ''
        string += classifier.__class__.__name__ + ' with ' + vectorizer.__class__.__name__

        # train
        vectorize_text = vectorizer.fit(train_data.features)
        train_vectorized_text = vectorize_text.transform(train_data.features)
        trained_classifier = classifier.fit(train_vectorized_text, train_data.label)
        train_score = trained_classifier.score(train_vectorized_text, train_data.label)
        train_f1_score = f1_score(trained_classifier.predict(train_vectorized_text), train_data.label)

        # score
        test_vectorized_text = vectorize_text.transform(test_data.features)
        test_score = trained_classifier.score(test_vectorized_text, test_data.label)
        test_f1_score = f1_score(trained_classifier.predict(test_vectorized_text), test_data.label)
        string += ' Has Scores: ' + ' Train : ' + str(train_score) + ' Test : ' + str(test_score) \
                    + ' Train : ' + ' and F1 Scores : ' + ' Train : ' + str(train_f1_score) + ' Test : ' \
                    + str(test_f1_score) + '\n'
        results.append(classifier.__class__.__name__ + '() , ' + vectorizer.__class__.__name__
                       + '() , ' + str(train_score) + ' , ' + str(test_score) + ' , ' + str(train_f1_score) 
                       + ' , ' + str(test_f1_score))
        print(string)
    return results

# %%
sms_data = pd.read_csv(r"D:\Narendra\AIGenie_Capstone_ALL\sms.csv", encoding = 'latin1')
sms_data['label'] = sms_data['RESULT'].replace({'ham':0, 'spam':1})
sms_data.head(5)
# Out:
#    No RESULT                                                SMS  label
# 0   1    ham  Go until jurong point, crazy.. Available only ...    0.0
# 1   2    ham                      Ok lar... Joking wif u oni...    0.0
# 2   3   spam  Free entry in 2 a wkly comp to win FA Cup fina...    1.0
# 3   4    ham  U dun say so early hor... U c already then say...    0.0
# 4   5    ham  Nah I don't think he goes to usf, he lives aro...    0.0

# %%
sms_data.columns = ['No', 'result', 'features', 'label']
test_data = sms_data[sms_data.isna().sum(axis = 1) > 0]
train_data = sms_data[sms_data.isna().sum(axis = 1) == 0]

# %%
train_data.shape, test_data.shape
# Out:
# ((5540, 4), (32, 4))

# %%
train_x, test_x = train_test_split(train_data[['features', 'label']], test_size = 0.2, 
                                    shuffle = True, stratify = train_data['label'])

# %%
models_summary = analyze_models(
    [
        BernoulliNB(),
        RandomForestClassifier(n_estimators=100, n_jobs=-1),
        AdaBoostClassifier(),
        BaggingClassifier(),
        ExtraTreesClassifier(),
        GradientBoostingClassifier(),
        DecisionTreeClassifier(),
        CalibratedClassifierCV(),
        DummyClassifier(),
        PassiveAggressiveClassifier(),
        RidgeClassifier(),
        RidgeClassifierCV(),
        SGDClassifier(),
        OneVsRestClassifier(SVC(kernel='linear')),
        OneVsRestClassifier(LogisticRegression()),
        KNeighborsClassifier()
    ],
    [
        CountVectorizer(),
        TfidfVectorizer(),
        HashingVectorizer()
    ],
    train_x,
    test_x
)
# Out:
# BernoulliNB with CountVectorizer Has Scores:  Train : 0.986687725631769 Test : 0.9828519855595668 Train :  and F1 Scores :  Train : 0.9478337754199824 Test : 0.9314079422382672
# BernoulliNB with TfidfVectorizer Has Scores:  Train : 0.986687725631769 Test : 0.9828519855595668 Train :  and F1 Scores :  Train : 0.9478337754199824 Test : 0.9314079422382672
# BernoulliNB with HashingVectorizer Has Scores:  Train : 0.8664259927797834 Test : 0.8664259927797834 Train :  and F1 Scores :  Train : 0.0 Test : 0.0
# RandomForestClassifier with CountVectorizer Has Scores:  Train : 1.0 Test : 0.983754512635379 Train :  and F1 Scores :  Train : 1.0 Test : 0.935251798561151
# RandomForestClassifier with TfidfVectorizer Has Scores:  Train : 1.0 Test : 0.9783393501805054 Train :  and F1 Scores :  Train : 1.0 Test : 0.911764705882353
# RandomForestClassifier with HashingVectorizer Has Scores:  Train : 1.0 Test : 0.9747292418772563 Train :  and F1 Scores :  Train : 1.0 Test : 0.8955223880597014
# AdaBoostClassifier with CountVectorizer Has Scores:  Train : 0.9796931407942239 Test : 0.973826714801444 Train :  and F1 Scores :  Train : 0.9200710479573713 Test : 0.8982456140350877
# AdaBoostClassifier with TfidfVectorizer Has Scores:  Train : 0.9853339350180506 Test : 0.970216606498195 Train :  and F1 Scores :  Train : 0.9432314410480349 Test : 0.882562277580071
# AdaBoostClassifier with HashingVectorizer Has Scores:  Train : 0.9792418772563177 Test : 0.9711191335740073 Train :  and F1 Scores :  Train : 0.9181494661921707 Test : 0.8857142857142858
# BaggingClassifier with CountVectorizer Has Scores:  Train : 0.9961642599277978 Test : 0.9711191335740073 Train :  and F1 Scores :  Train : 0.9854824935952177 Test : 0.8881118881118881
# BaggingClassifier with TfidfVectorizer Has Scores:  Train : 0.9977436823104693 Test : 0.9792418772563177 Train :  and F1 Scores :  Train : 0.9915110356536502 Test : 0.9198606271777002
# BaggingClassifier with HashingVectorizer Has Scores:  Train : 0.9959386281588448 Test : 0.9756317689530686 Train :  and F1 Scores :  Train : 0.9845890410958904 Test : 0.9052631578947368
# ExtraTreesClassifier with CountVectorizer Has Scores:  Train : 1.0 Test : 0.9882671480144405 Train :  and F1 Scores :  Train : 1.0 Test : 0.9540636042402826
# ExtraTreesClassifier with TfidfVectorizer Has Scores:  Train : 1.0 Test : 0.9855595667870036 Train :  and F1 Scores :  Train : 1.0 Test : 0.9428571428571428
# ExtraTreesClassifier with HashingVectorizer Has Scores:  Train : 1.0 Test : 0.9774368231046932 Train :  and F1 Scores :  Train : 1.0 Test : 0.9077490774907748
# GradientBoostingClassifier with CountVectorizer Has Scores:  Train : 0.9826263537906137 Test : 0.9747292418772563 Train :  and F1 Scores :  Train : 0.9308176100628931 Test : 0.8970588235294118
# GradientBoostingClassifier with TfidfVectorizer Has Scores:  Train : 0.9839801444043321 Test : 0.9720216606498195 Train :  and F1 Scores :  Train : 0.9372236958443856 Test : 0.8864468864468864
# GradientBoostingClassifier with HashingVectorizer Has Scores:  Train : 0.9853339350180506 Test : 0.9720216606498195 Train :  and F1 Scores :  Train : 0.9422222222222222 Test : 0.8872727272727272
# DecisionTreeClassifier with CountVectorizer Has Scores:  Train : 1.0 Test : 0.9720216606498195 Train :  and F1 Scores :  Train : 1.0 Test : 0.8934707903780069
# DecisionTreeClassifier with TfidfVectorizer Has Scores:  Train : 1.0 Test : 0.9684115523465704 Train :  and F1 Scores :  Train : 1.0 Test : 0.8771929824561404
# DecisionTreeClassifier with HashingVectorizer Has Scores:  Train : 1.0 Test : 0.9720216606498195 Train :  and F1 Scores :  Train : 1.0 Test : 0.8927335640138409
# CalibratedClassifierCV with CountVectorizer Has Scores:  Train : 1.0 Test : 0.9882671480144405 Train :  and F1 Scores :  Train : 1.0 Test : 0.9547038327526132
# CalibratedClassifierCV with TfidfVectorizer Has Scores:  Train : 0.9995487364620939 Test : 0.990072202166065 Train :  and F1 Scores :  Train : 0.9983136593591906 Test : 0.9624573378839592
# CalibratedClassifierCV with HashingVectorizer Has Scores:  Train : 0.9984205776173285 Test : 0.9873646209386282 Train :  and F1 Scores :  Train : 0.9940728196443691 Test : 0.952054794520548
# D:\Anaconda\lib\site-packages\sklearn\dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)
# DummyClassifier with CountVectorizer Has Scores:  Train : 0.7736913357400722 Test : 0.7671480144404332 Train :  and F1 Scores :  Train : 0.12595744680851065 Test : 0.13523131672597866
# DummyClassifier with TfidfVectorizer Has Scores:  Train : 0.7680505415162455 Test : 0.7788808664259927 Train :  and F1 Scores :  Train : 0.12294372294372295 Test : 0.13058419243986255
# DummyClassifier with HashingVectorizer Has Scores:  Train : 0.7673736462093863 Test : 0.7671480144404332 Train :  and F1 Scores :  Train : 0.14117647058823526 Test : 0.14545454545454545
# PassiveAggressiveClassifier with CountVectorizer Has Scores:  Train : 1.0 Test : 0.9864620938628159 Train :  and F1 Scores :  Train : 1.0 Test : 0.9477351916376306
# PassiveAggressiveClassifier with TfidfVectorizer Has Scores:  Train : 1.0 Test : 0.9891696750902527 Train :  and F1 Scores :  Train : 1.0 Test : 0.9591836734693877
# PassiveAggressiveClassifier with HashingVectorizer Has Scores:  Train : 1.0 Test : 0.9855595667870036 Train :  and F1 Scores :  Train : 1.0 Test : 0.9444444444444445
# RidgeClassifier with CountVectorizer Has Scores:  Train : 1.0 Test : 0.983754512635379 Train :  and F1 Scores :  Train : 1.0 Test : 0.935251798561151
# RidgeClassifier with TfidfVectorizer Has Scores:  Train : 0.9972924187725631 Test : 0.9864620938628159 Train :  and F1 Scores :  Train : 0.9897610921501706 Test : 0.9477351916376306
# RidgeClassifier with HashingVectorizer Has Scores:  Train : 0.9943592057761733 Test : 0.983754512635379 Train :  and F1 Scores :  Train : 0.9784296807592753 Test : 0.9366197183098591
# RidgeClassifierCV with CountVectorizer Has Scores:  Train : 1.0 Test : 0.983754512635379 Train :  and F1 Scores :  Train : 1.0 Test : 0.935251798561151
# RidgeClassifierCV with TfidfVectorizer Has Scores:  Train : 1.0 Test : 0.9873646209386282 Train :  and F1 Scores :  Train : 1.0 Test : 0.951048951048951
# RidgeClassifierCV with HashingVectorizer Has Scores:  Train : 0.9997743682310469 Test : 0.9855595667870036 Train :  and F1 Scores :  Train : 0.9991546914623838 Test : 0.943661971830986
# SGDClassifier with CountVectorizer Has Scores:  Train : 0.9993231046931408 Test : 0.9882671480144405 Train :  and F1 Scores :  Train : 0.9974640743871512 Test : 0.9547038327526132
# SGDClassifier with TfidfVectorizer Has Scores:  Train : 0.9990974729241877 Test : 0.9909747292418772 Train :  and F1 Scores :  Train : 0.9966159052453469 Test : 0.9657534246575342
# SGDClassifier with HashingVectorizer Has Scores:  Train : 0.9970667870036101 Test : 0.9846570397111913 Train :  and F1 Scores :  Train : 0.9888983774551665 Test : 0.9403508771929824
# OneVsRestClassifier with CountVectorizer Has Scores:  Train : 0.9997743682310469 Test : 0.9882671480144405 Train :  and F1 Scores :  Train : 0.9991546914623838 Test : 0.9543859649122808
# OneVsRestClassifier with TfidfVectorizer Has Scores:  Train : 0.9963898916967509 Test : 0.990072202166065 Train :  and F1 Scores :  Train : 0.9863247863247863 Test : 0.9621993127147767
# OneVsRestClassifier with HashingVectorizer Has Scores:  Train : 0.993456678700361 Test : 0.9864620938628159 Train :  and F1 Scores :  Train : 0.9749784296807593 Test : 0.9473684210526316
# OneVsRestClassifier with CountVectorizer Has Scores:  Train : 0.9975180505415162 Test : 0.9855595667870036 Train :  and F1 Scores :  Train : 0.9906223358908782 Test : 0.943661971830986
# OneVsRestClassifier with TfidfVectorizer Has Scores:  Train : 0.9749548736462094 Test : 0.9747292418772563 Train :  and F1 Scores :  Train : 0.8969359331476323 Test : 0.8955223880597014
# OneVsRestClassifier with HashingVectorizer Has Scores:  Train : 0.9758574007220217 Test : 0.9720216606498195 Train :  and F1 Scores :  Train : 0.9021043000914915 Test : 0.8838951310861423
# KNeighborsClassifier with CountVectorizer Has Scores:  Train : 0.9305054151624549 Test : 0.9223826714801444 Train :  and F1 Scores :  Train : 0.6484018264840182 Test : 0.5904761904761905
# KNeighborsClassifier with TfidfVectorizer Has Scores:  Train : 0.9189981949458483 Test : 0.9151624548736462 Train :  and F1 Scores :  Train : 0.5648484848484848 Test : 0.5346534653465346
# KNeighborsClassifier with HashingVectorizer Has Scores:  Train : 0.9305054151624549 Test : 0.9250902527075813 Train :  and F1 Scores :  Train : 0.65 Test : 0.6103286384976526

# %%
model_summary = list(map(lambda x:x.split(','), models_summary))
models_summary = pd.DataFrame(model_summary, columns = ['classifier', 'vectorizer', 'train_score', 
                                                        'test_score', 'train_f1_score', 'test_f1_score'])

# %%
models_summary.sort_values(['test_f1_score', 'train_f1_score'],  ascending = False)
# Out:
#                         classifier             vectorizer  \
# 37                SGDClassifier()      TfidfVectorizer()
# 22       CalibratedClassifierCV()      TfidfVectorizer()
# 40          OneVsRestClassifier()      TfidfVectorizer()
# 28  PassiveAggressiveClassifier()      TfidfVectorizer()
# 21       CalibratedClassifierCV()      CountVectorizer()
# 36                SGDClassifier()      CountVectorizer()
# 39          OneVsRestClassifier()      CountVectorizer()
# 12         ExtraTreesClassifier()      CountVectorizer()
# 23       CalibratedClassifierCV()    HashingVectorizer()
# 34            RidgeClassifierCV()      TfidfVectorizer()
# 27  PassiveAggressiveClassifier()      CountVectorizer()
# 31              RidgeClassifier()      TfidfVectorizer()
# 41          OneVsRestClassifier()    HashingVectorizer()
# 29  PassiveAggressiveClassifier()    HashingVectorizer()
# 35            RidgeClassifierCV()    HashingVectorizer()
# 42          OneVsRestClassifier()      CountVectorizer()
# 13         ExtraTreesClassifier()      TfidfVectorizer()
# 38                SGDClassifier()    HashingVectorizer()
# 32              RidgeClassifier()    HashingVectorizer()
# 3        RandomForestClassifier()      CountVectorizer()
# 30              RidgeClassifier()      CountVectorizer()
# 33            RidgeClassifierCV()      CountVectorizer()
# 0                   BernoulliNB()      CountVectorizer()
# 1                   BernoulliNB()      TfidfVectorizer()
# 10            BaggingClassifier()      TfidfVectorizer()
# 4        RandomForestClassifier()      TfidfVectorizer()
# 14         ExtraTreesClassifier()    HashingVectorizer()
# 11            BaggingClassifier()    HashingVectorizer()
# 6            AdaBoostClassifier()      CountVectorizer()
# 15   GradientBoostingClassifier()      CountVectorizer()
# 5        RandomForestClassifier()    HashingVectorizer()
# 43          OneVsRestClassifier()      TfidfVectorizer()
# 18       DecisionTreeClassifier()      CountVectorizer()
# 20       DecisionTreeClassifier()    HashingVectorizer()
# 9             BaggingClassifier()      CountVectorizer()
# 17   GradientBoostingClassifier()    HashingVectorizer()
# 16   GradientBoostingClassifier()      TfidfVectorizer()
# 8            AdaBoostClassifier()    HashingVectorizer()
# 44          OneVsRestClassifier()    HashingVectorizer()
# 7            AdaBoostClassifier()      TfidfVectorizer()
# 19       DecisionTreeClassifier()      TfidfVectorizer()
# 47         KNeighborsClassifier()    HashingVectorizer()
# 45         KNeighborsClassifier()      CountVectorizer()
# 46         KNeighborsClassifier()      TfidfVectorizer()
# 26              DummyClassifier()    HashingVectorizer()
# 24              DummyClassifier()      CountVectorizer()
# 25              DummyClassifier()      TfidfVectorizer()
# 2                   BernoulliNB()    HashingVectorizer()
#
#              train_score            test_score         train_f1_score  \
# 37   0.9990974729241877    0.9909747292418772     0.9966159052453469
# 22   0.9995487364620939     0.990072202166065     0.9983136593591906
# 40   0.9963898916967509     0.990072202166065     0.9863247863247863
# 28                  1.0    0.9891696750902527                    1.0
# 21                  1.0    0.9882671480144405                    1.0
# 36   0.9993231046931408    0.9882671480144405     0.9974640743871512
# 39   0.9997743682310469    0.9882671480144405     0.9991546914623838
# 12                  1.0    0.9882671480144405                    1.0
# 23   0.9984205776173285    0.9873646209386282     0.9940728196443691
# 34                  1.0    0.9873646209386282                    1.0
# 27                  1.0    0.9864620938628159                    1.0
# 31   0.9972924187725631    0.9864620938628159     0.9897610921501706
# 41    0.993456678700361    0.9864620938628159     0.9749784296807593
# 29                  1.0    0.9855595667870036                    1.0
# 35   0.9997743682310469    0.9855595667870036     0.9991546914623838
# 42   0.9975180505415162    0.9855595667870036     0.9906223358908782
# 13                  1.0    0.9855595667870036                    1.0
# 38   0.9970667870036101    0.9846570397111913     0.9888983774551665
# 32   0.9943592057761733     0.983754512635379     0.9784296807592753
# 3                   1.0     0.983754512635379                    1.0
# 30                  1.0     0.983754512635379                    1.0
# 33                  1.0     0.983754512635379                    1.0
# 0     0.986687725631769    0.9828519855595668     0.9478337754199824
# 1     0.986687725631769    0.9828519855595668     0.9478337754199824
# 10   0.9977436823104693    0.9792418772563177     0.9915110356536502
# 4                   1.0    0.9783393501805054                    1.0
# 14                  1.0    0.9774368231046932                    1.0
# 11   0.9959386281588448    0.9756317689530686     0.9845890410958904
# 6    0.9796931407942239     0.973826714801444     0.9200710479573713
# 15   0.9826263537906137    0.9747292418772563     0.9308176100628931
# 5                   1.0    0.9747292418772563                    1.0
# 43   0.9749548736462094    0.9747292418772563     0.8969359331476323
# 18                  1.0    0.9720216606498195                    1.0
# 20                  1.0    0.9720216606498195                    1.0
# 9    0.9961642599277978    0.9711191335740073     0.9854824935952177
# 17   0.9853339350180506    0.9720216606498195     0.9422222222222222
# 16   0.9839801444043321    0.9720216606498195     0.9372236958443856
# 8    0.9792418772563177    0.9711191335740073     0.9181494661921707
# 44   0.9758574007220217    0.9720216606498195     0.9021043000914915
# 7    0.9853339350180506     0.970216606498195     0.9432314410480349
# 19                  1.0    0.9684115523465704                    1.0
# 47   0.9305054151624549    0.9250902527075813                   0.65
# 45   0.9305054151624549    0.9223826714801444     0.6484018264840182
# 46   0.9189981949458483    0.9151624548736462     0.5648484848484848
# 26   0.7673736462093863    0.7671480144404332    0.14117647058823526
# 24   0.7736913357400722    0.7671480144404332    0.12595744680851065
# 25   0.7680505415162455    0.7788808664259927    0.12294372294372295
# 2    0.8664259927797834    0.8664259927797834                    0.0
#
#            test_f1_score
# 37    0.9657534246575342
# 22    0.9624573378839592
# 40    0.9621993127147767
# 28    0.9591836734693877
# 21    0.9547038327526132
# 36    0.9547038327526132
# 39    0.9543859649122808
# 12    0.9540636042402826
# 23     0.952054794520548
# 34     0.951048951048951
# 27    0.9477351916376306
# 31    0.9477351916376306
# 41    0.9473684210526316
# 29    0.9444444444444445
# 35     0.943661971830986
# 42     0.943661971830986
# 13    0.9428571428571428
# 38    0.9403508771929824
# 32    0.9366197183098591
# 3      0.935251798561151
# 30     0.935251798561151
# 33     0.935251798561151
# 0     0.9314079422382672
# 1     0.9314079422382672
# 10    0.9198606271777002
# 4      0.911764705882353
# 14    0.9077490774907748
# 11    0.9052631578947368
# 6     0.8982456140350877
# 15    0.8970588235294118
# 5     0.8955223880597014
# 43    0.8955223880597014
# 18    0.8934707903780069
# 20    0.8927335640138409
# 9     0.8881118881118881
# 17    0.8872727272727272
# 16    0.8864468864468864
# 8     0.8857142857142858
# 44    0.8838951310861423
# 7      0.882562277580071
# 19    0.8771929824561404
# 47    0.6103286384976526
# 45    0.5904761904761905
# 46    0.5346534653465346
# 26   0.14545454545454545
# 24   0.13523131672597866
# 25   0.13058419243986255
# 2                    0.0

# %%
vectorize_text = TfidfVectorizer(encoding = 'latin1').fit(train_x.features)
train_vectorized_text = vectorize_text.transform(train_x.features)

# %%
cross_val_score(PassiveAggressiveClassifier(), train_vectorized_text, train_x.label, cv=10)
# Out:
# array([0.97972973, 0.98873874, 0.97968397, 0.97968397, 0.98419865,
#        0.98871332, 0.98194131, 0.98871332, 0.98419865, 0.97968397])

# %%
clf = PassiveAggressiveClassifier().fit(train_vectorized_text, train_x.label)

# %%
test_vectorizer_text = vectorize_text.transform(test_x.features)

# %%
np.unique(clf.predict(test_vectorizer_text), return_counts = True)
# Out:
# (array([0., 1.]), array([962, 146], dtype=int64))

# %%
np.unique(test_x.label, return_counts = True)
# Out:
# (array([0., 1.]), array([960, 148], dtype=int64))
